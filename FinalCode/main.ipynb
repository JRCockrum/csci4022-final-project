# %% [markdown]
# # Clustering & Recommendation of IT Support Tickets
#
# ### Contributers: Jackson Cockrum , Charlotte Hauke
# ### CSCI 4022 - Advanced Data Science Spring 2025

# %%
#Imports
import pandas as pd
import string
import matplotlib.pyplot as plt
import seaborn as sns
import sys
import numpy as np
import re
sys.path.append("../src")

# %%
#Import Data

og_df = pd.read_csv("./data/dataset-tickets-multi-lang-4-20k.csv")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   subject   18539 non-null  object
#  1   body      19998 non-null  object
#  2   answer    19996 non-null  object
#  3   type      20000 non-null  object
#  4   queue     20000 non-null  object
#  5   priority  20000 non-null  object
#  6   language  20000 non-null  object
#  7   tag_1     20000 non-null  object
#  8   tag_2     19954 non-null  object
#  9   tag_3     19905 non-null  object
#  10  tag_4     18461 non-null  object
#  11  tag_5     13091 non-null  object
#  12  tag_6     7351 non-null   object
#  13  tag_7     3928 non-null   object
#  14  tag_8     1907 non-null   object
# dtypes: object(15)
# memory usage: 2.3+ MB
#                                              subject  \
# 0  Unvorhergesehener Absturz der Datenanalyse-Pla...
# 1                           Customer Support Inquiry
# 2                      Data Analytics for Investment
# 3                 Krankenhaus-Dienstleistung-Problem
# 4                                           Security
#
#                                                 body  \
# 0  Die Datenanalyse-Plattform brach unerwartet ab...
# 1  Seeking information on digital strategies that...
# 2  I am contacting you to request information on ...
# 3  Ein Medien-Daten-Sperrverhalten trat aufgrund ...
# 4  Dear Customer Support, I am reaching out to in...
#
#                                               answer      type  \
# 0  Ich werde Ihnen bei der Lösung des Problems he...  Incident
# 1  We offer a variety of digital strategies and s...   Request
# 2  I am here to assist you with data analytics to...   Request
# 3  Zurück zur E-Mail-Beschwerde über den Sperrver...  Incident
# 4  Dear [name], we take the security of medical d...   Request
#
#               queue priority language      tag_1      tag_2       tag_3  \
# 0   General Inquiry      low       de      Crash  Technical         Bug
# 1  Customer Service   medium       en   Feedback      Sales          IT
# 2  Customer Service   medium       en  Technical    Product    Guidance
# 3  Customer Service     high       de   Security     Breach       Login
# 4  Customer Service   medium       en   Security   Customer  Compliance
#
#            tag_4          tag_5       tag_6          tag_7 tag_8
# 0       Hardware     Resolution      Outage  Documentation   NaN
# 1   Tech Support            NaN         NaN            NaN   NaN
# 2  Documentation    Performance     Feature            NaN   NaN
# 3    Maintenance       Incident  Resolution       Feedback   NaN
# 4         Breach  Documentation    Guidance            NaN   NaN

# %% [markdown]
# # Clean and Preprocess Data

# %%
#Remove tickets not in english
df = og_df[og_df['language']=="en"]
df = df.drop(columns='language')
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11923 entries, 1 to 19997
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   subject   10891 non-null  object
#  1   body      11922 non-null  object
#  2   answer    11920 non-null  object
#  3   type      11923 non-null  object
#  4   queue     11923 non-null  object
#  5   priority  11923 non-null  object
#  6   tag_1     11923 non-null  object
#  7   tag_2     11913 non-null  object
#  8   tag_3     11879 non-null  object
#  9   tag_4     11050 non-null  object
#  10  tag_5     7885 non-null   object
#  11  tag_6     4538 non-null   object
#  12  tag_7     2565 non-null   object
#  13  tag_8     1327 non-null   object
# dtypes: object(14)
# memory usage: 1.4+ MB
#                                              subject  \
# 1                           Customer Support Inquiry
# 2                      Data Analytics for Investment
# 4                                           Security
# 5  Concerns About Securing Medical Data on 2-in-1...
# 7                           Problem with Integration
#
#                                                 body  \
# 1  Seeking information on digital strategies that...
# 2  I am contacting you to request information on ...
# 4  Dear Customer Support, I am reaching out to in...
# 5  Inquiring about best practices for securing me...
# 7  The integration stopped working unexpectedly, ...
#
#                                               answer     type  \
# 1  We offer a variety of digital strategies and s...  Request
# 2  I am here to assist you with data analytics to...  Request
# 4  Dear [name], we take the security of medical d...  Request
# 5  Thank you for your concern regarding securing ...  Request
# 7  I will look into the problem and call you at <...  Problem
#
#                queue priority      tag_1        tag_2       tag_3  \
# 1   Customer Service   medium   Feedback        Sales          IT
# 2   Customer Service   medium  Technical      Product    Guidance
# 4   Customer Service   medium   Security     Customer  Compliance
# 5  Technical Support   medium   Security      Product     Feature
# 7         IT Support     high  Technical  Integration         Bug
#
#            tag_4          tag_5          tag_6 tag_7 tag_8
# 1   Tech Support            NaN            NaN   NaN   NaN
# 2  Documentation    Performance        Feature   NaN   NaN
# 4         Breach  Documentation       Guidance   NaN   NaN
# 5             IT   Tech Support            NaN   NaN   NaN
# 7     Resolution         Outage  Documentation   NaN   NaN

# %%
# df.isnull().sum()
df = df.drop(columns=['tag_6', 'tag_7', 'tag_8'])
df.isnull().sum()
# Out:
# subject     1032
# body           1
# answer         3
# type           0
# queue          0
# priority       0
# tag_1          0
# tag_2         10
# tag_3         44
# tag_4        873
# tag_5       4038
# dtype: int64

# %%
def clean_text(text):
    if pd.isnull(text):
        return "" 
    text = text.lower() 
    text = re.sub(r'[^a-z\s]', '', text)  # Remove everything except letters and spaces
    text = re.sub(r'\s+', ' ', text).strip()  # change multiple spaces into one
    return text

# %%
df = df.dropna(subset=['body', 'answer'])
df['body'] = df['body'].apply(clean_text)
tag_columns = ['tag_1', 'tag_2', 'tag_3', 'tag_4', 'tag_5']
df[tag_columns] = df[tag_columns].fillna('Unknown')
df = df.drop(columns='subject')
df.isnull().sum()
# Out:
# body        0
# answer      0
# type        0
# queue       0
# priority    0
# tag_1       0
# tag_2       0
# tag_3       0
# tag_4       0
# tag_5       0
# dtype: int64

# %%
#Check for weird values
for col in df:
    num_unique = df[col].nunique()
    print(col, num_unique)

print(df['type'].unique())
print(df['queue'].unique())
print(df['priority'].unique())
# Out:
# body 11909
# answer 11919
# type 4
# queue 10
# priority 3
# tag_1 87
# tag_2 177
# tag_3 298
# tag_4 401
# tag_5 478
# ['Request' 'Problem' 'Incident' 'Change']
# ['Customer Service' 'Technical Support' 'IT Support' 'Product Support'
#  'Billing and Payments' 'Service Outages and Maintenance'
#  'Human Resources' 'Returns and Exchanges' 'Sales and Pre-Sales'
#  'General Inquiry']
# ['medium' 'high' 'low']

# %% [markdown]
# # Exploratory Data Analysis

# %%
# Plot distribution of Type column
plt.figure(figsize=(5, 3))
sns.countplot(x='type', data=df,palette='Pastel1',hue='type')
plt.title('Distribution of Type')
plt.xlabel('Type')
plt.ylabel('Count')
plt.show()

# Plot distribution of Queue column
plt.figure(figsize=(7, 3))
sns.countplot(x='queue', data=df, hue='queue',palette='Pastel1')
plt.title('Distribution of Queue')
plt.xlabel('Queue')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# Plot distribution of Priority column
plt.figure(figsize=(5, 3))
sns.countplot(x='priority', data=df, palette='Pastel1',hue='priority')
plt.title('Distribution of Priority')
plt.xlabel('Priority')
plt.ylabel('Count')
plt.show()


# Plot distribution of body length
plt.figure(figsize=(5, 3))
sns.histplot(df['body'].str.split().apply(len), bins=50, color='skyblue')
plt.title('Distribution of Ticket Body Length')
plt.xlabel('Number of Words in Body')
plt.ylabel('Count')
plt.show()

# Plot distribution of answer length
plt.figure(figsize=(5, 3))
sns.histplot(df['answer'].str.split().apply(len), bins=50, color='lightcoral')
plt.title('Distribution of Ticket Answer Length')
plt.xlabel('Number of Words in Answer')
plt.ylabel('Count')
plt.show()

# %%
#Print mean of Answer and Body length
print("Mean ticket body length: ", df['body'].str.split().apply(len).mean(), " words.")
print("Mean ticket body length: ", df['answer'].str.split().apply(len).mean(), " words.")
# Out:
# Mean ticket body length:  57.3139525127947  words.
# Mean ticket body length:  60.83757026596191  words.

# %% [markdown]
# # K-Modes Clustering

# %%
#Cluster class

import pandas as pd

class Cluster:
    def __init__(self, kmodes):
        self._centroid = None
        self._data =  [] # list of indexes
        self._kmodes = kmodes

    def get_centroid(self):
        return self._centroid

    def get_data(self):
        return self._data
    
    def get_cost(self):
        cost = 0
        row_vals = [self._kmodes.get_row(idx) for idx in self._data]
        for row in row_vals:
            cost += self._kmodes._dist(self._centroid, row)
        return cost
    
    def has_row(self, row_num):
        return row_num in self._data
    
    def add_row(self, row):
        if not self.has_row(row):
            self._data.append(row)

    def drop_row(self, row):
        if self.has_row(row):
            self._data.remove(row)

    def update_centroid(self):
        if not self._data:
            self._centroid = None
            return
        
        row_vals = [self._kmodes.get_row(idx) for idx in self._data]
        df = pd.DataFrame(row_vals)
        self._centroid = df.mode().iloc[0].values

# %%
#kmodes class

import random

class KModes:
    def __init__(self, k: int, data: pd.DataFrame):
        self._data = data
        self._clusters = [Cluster(self) for _ in range(k)]

        # Random cluster init
        random_indices = random.sample(range(len(data)), k)
        for cluster, idx in zip(self._clusters, random_indices):
            cluster.add_row(idx)
            cluster.update_centroid()

        # Clustering
        while True:
            clust_changes = 0
            for row_num in range(len(self._data)):
                centroids = self.get_centroids()
                row_vals = self.get_row(row_num)

                closest_cluster = 0
                closest_dist = self._dist(centroids[0], row_vals)

                for clust_num in range(len(self._clusters)):
                    d = self._dist(centroids[clust_num], row_vals)
                    if d < closest_dist:
                        closest_cluster = clust_num
                        closest_dist = d

                if not self._clusters[closest_cluster].has_row(row_num):
                    current_cluster = next((clust for clust in self._clusters if clust.has_row(row_num)), None)
                    if current_cluster is not None:
                        current_cluster.drop_row(row_num)

                    self._clusters[closest_cluster].add_row(row_num)
                    clust_changes += 1
            
            if clust_changes == 0:
                return
            else:
                self._update_centroids()

    def get_clusters(self):
        return self._clusters
    
    def get_centroids(self):
        return [clust.get_centroid() for clust in self._clusters]

    def get_row(self, index):
        try:
            return self._data.iloc[index, :].values
        except IndexError as e:
            raise IndexError(f"Index {index} is out of bounds.") from e
        
    def get_cost(self):
        cost = 0
        for clust in self._clusters:
            cost += clust.get_cost()
        return cost
        
    def _dist(self, x, y):
        diffs = 0
        for x_a, y_a in zip(x,y):
            if x_a != y_a:
                diffs += 1
        return diffs

    def _update_centroids(self):
        for clust in self._clusters:
            clust.update_centroid()

# %%
clustering_df = df.drop(columns=['body', 'answer'])
# results = []
# for k in range(1,11):
#     costs = []
#     for _ in range(10):
#         kmode = KModes(k, clustering_df)
#         costs.append(kmode.get_cost())

#     results.append(min(costs))

    
# k_values = list(range(1, 11))
# plt.figure(figsize=(8, 6))
# plt.plot(k_values, results, marker='o', linestyle='-')


# plt.xlabel("Number of Clusters")
# plt.ylabel("Best Observed Cost")
# plt.title("Clustering Cost vs # of Clusters")
# plt.xticks(k_values)  
# plt.grid(True)
# plt.show()

# %%
#perform clustering
import numpy as np
best_cost = np.inf

for _ in range(10):
    kmode = KModes(6, clustering_df)
    cost = kmode.get_cost()
    if cost < best_cost:
        best_cost = cost
        clusters = kmode.get_clusters()

# %% [markdown]
# ## Explore Cluster Results

# %%
cluster_data =[]
for clust in clusters:
    cluster_data.append(clustering_df.iloc[clust.get_data(), :])

cluster_data[0].head()
# Out:
#          type                            queue priority      tag_1  \
# 9332   Change  Service Outages and Maintenance     high     Outage
# 16     Change                  Product Support      low    Feature
# 28    Request  Service Outages and Maintenance     high  Technical
# 34    Request                 Customer Service      low   Feedback
# 39     Change                       IT Support   medium    Feature
#
#             tag_2         tag_3        tag_4            tag_5
# 9332   Disruption      Recovery  Performance          Unknown
# 16             IT  Tech Support      Unknown          Unknown
# 28    Integration      Software   Guidelines  Troubleshooting
# 34          Sales  Tech Support      Unknown          Unknown
# 39             IT  Tech Support      Unknown          Unknown

# %%
#count number of tags in each cluster
tag_cols = ['tag_1', 'tag_2', 'tag_3', 'tag_4', 'tag_5']

for i, cluster_df in enumerate(cluster_data):
    print(f"\n--- Cluster {i} Tag Counts ---")
    for tag in range(len(tag_cols)):
        print(f"\n{tag} value counts:")
        print(cluster_df.iloc[:,tag].value_counts())
# Out:
# --- Cluster 0 Tag Counts ---
#
# 0 value counts:
# type
# Request     1795
# Incident     605
# Change       425
# Problem      342
# Name: count, dtype: int64
#
# 1 value counts:
# queue
# Technical Support                  1155
# Product Support                     465
# Customer Service                    453
# IT Support                          386
# Billing and Payments                246
# Returns and Exchanges               151
# Service Outages and Maintenance     115
# Sales and Pre-Sales                  93
# Human Resources                      55
# General Inquiry                      48
# Name: count, dtype: int64
#
# 2 value counts:
# priority
# high      1948
# medium     731
# low        488
# Name: count, dtype: int64
#
# 3 value counts:
# tag_1
# Security                                                                                                      1282
# Feedback                                                                                                       461
# Feature                                                                                                        357
# Technical                                                                                                      312
# Customer                                                                                                       163
# Performance                                                                                                    151
# Documentation                                                                                                   67
# Product                                                                                                         64
# Sales                                                                                                           45
# Crash                                                                                                           34
# Guidance                                                                                                        26
# Billing                                                                                                         25
# Outage                                                                                                          21
# IT                                                                                                              21
# Digital                                                                                                         13
# Network                                                                                                         11
# Marketing                                                                                                       10
# Onboarding                                                                                                       9
# Account                                                                                                          8
# Bug                                                                                                              8
# Integration                                                                                                      7
# Breach                                                                                                           7
# Login                                                                                                            6
# Training                                                                                                         5
# General                                                                                                          5
# Payment                                                                                                          5
# Disruption                                                                                                       4
# Tech Support                                                                                                     3
# Employee                                                                                                         3
# Strategy                                                                                                         3
# Campaign                                                                                                         3
# HR                                                                                                               2
# Brand                                                                                                            2
# Returns                                                                                                          2
# Inquiry                                                                                                          2
# Refund                                                                                                           1
# DigitalMarketing                                                                                                 1
# Notification                                                                                                     1
# Hardware                                                                                                         1
# Customer,Sales,Strategy,Online Presence,Method,Website,Interaction                                               1
# Pricing                                                                                                          1
# Upgrade                                                                                                          1
# Billing,Product,Error,Data Analytics,Breach                                                                      1
# Maintenance                                                                                                      1
# Cybersecurity                                                                                                    1
# Brand Growth                                                                                                     1
# Incident                                                                                                         1
# Digital,Campaign,Performance,Issue,Resolution,Feedback                                                           1
# Technical,Bug,Security,Crash,Documentation,Guidance                                                              1
# Technical,Crash,Ubuntu,Bug,Resolution                                                                            1
# Digital,Campaign,Performance,Issue,Resolution,Urgency,Communication,Action,Algorithm,Maintenance,Follow-Up       1
# Technical,Customer,Plugin,Bug,Synchronization,Guidance                                                           1
# Medical                                                                                                          1
# Return                                                                                                           1
# Data                                                                                                             1
# Name: count, dtype: int64
#
# 4 value counts:
# tag_2
# IT               702
# Documentation    296
# Sales            269
# Feedback         214
# Breach           205
#                 ...
# Capacity           1
# Improvement        1
# AdTargeting        1
# Dashboard          1
# Access             1
# Name: count, Length: 99, dtype: int64
#
# --- Cluster 1 Tag Counts ---
#
# 0 value counts:
# type
# Problem     956
# Incident    829
# Request     562
# Change      305
# Name: count, dtype: int64
#
# 1 value counts:
# queue
# Customer Service                   897
# Product Support                    538
# Technical Support                  441
# IT Support                         323
# Returns and Exchanges              143
# Billing and Payments               110
# Sales and Pre-Sales                 77
# Human Resources                     57
# General Inquiry                     33
# Service Outages and Maintenance     33
# Name: count, dtype: int64
#
# 2 value counts:
# priority
# medium    1709
# low        499
# high       444
# Name: count, dtype: int64
#
# 3 value counts:
# tag_1
# Bug                                                            654
# Feedback                                                       425
# Security                                                       359
# Feature                                                        264
# Performance                                                    225
# Technical                                                      199
# Network                                                        110
# Customer                                                        90
# Crash                                                           56
# Documentation                                                   34
# Login                                                           33
# Product                                                         30
# Campaign                                                        27
# Outage                                                          20
# Billing                                                         17
# Disruption                                                      15
# Sales                                                            9
# HR                                                               9
# Marketing                                                        6
# Guidance                                                         6
# Breach                                                           6
# Returns                                                          6
# IT                                                               5
# Data                                                             3
# Digital                                                          3
# Payment                                                          3
# Integration                                                      3
# Incident                                                         3
# Maintenance                                                      3
# Strategy                                                         2
# Account                                                          2
# Ad                                                               2
# Digital Campaign                                                 2
# Employee                                                         2
# Hardware                                                         1
# General                                                          1
# Investment                                                       1
# Malware                                                          1
# Data Leak                                                        1
# Lead                                                             1
# Access                                                           1
# Business                                                         1
# Notification                                                     1
# Urgent                                                           1
# Technical,Crash,Software,Bug,Hardware,Outage,Maintenance         1
# Gaming                                                           1
# Slow,Growth,Strategy,Improvement,Issue,Solution,Performance      1
# Training                                                         1
# SocialMedia                                                      1
# Upgrade                                                          1
# Return                                                           1
# Tech Support                                                     1
# Campaigns                                                        1
# Name: count, dtype: int64
#
# 4 value counts:
# tag_2
# Performance      1008
# Sales             221
# Feedback          193
# Documentation     164
# Bug               143
#                  ...
# Social Media        1
# Access              1
# Request             1
# Assistance          1
# Support             1
# Name: count, Length: 80, dtype: int64
#
# --- Cluster 2 Tag Counts ---
#
# 0 value counts:
# type
# Problem     496
# Request     419
# Change      296
# Incident    230
# Name: count, dtype: int64
#
# 1 value counts:
# queue
# Product Support                    583
# Customer Service                   184
# IT Support                         154
# Returns and Exchanges              116
# Technical Support                  111
# Billing and Payments               104
# Sales and Pre-Sales                 69
# General Inquiry                     45
# Service Outages and Maintenance     40
# Human Resources                     35
# Name: count, dtype: int64
#
# 2 value counts:
# priority
# low       833
# medium    345
# high      263
# Name: count, dtype: int64
#
# 3 value counts:
# tag_1
# Technical                                     941
# Feedback                                       91
# Customer                                       65
# Feature                                        61
# Billing                                        52
# Security                                       40
# Performance                                    31
# Product                                        24
# Login                                          18
# Marketing                                      11
# Sales                                          11
# HR                                             10
# Onboarding                                      7
# Outage                                          7
# Crash                                           6
# IT                                              6
# Backup                                          5
# Maintenance                                     5
# Bug                                             4
# Campaign                                        4
# Return                                          4
# Integration                                     3
# Documentation                                   3
# Incident                                        3
# Disruption                                      2
# Cybersecurity                                   2
# Breach                                          2
# Network                                         2
# Campaigns                                       2
# Social                                          2
# SocialMedia                                     2
# Shipment                                        2
# Social Media                                    2
# Guidance                                        2
# Secure                                          1
# Pricing                                         1
# Digital                                         1
# Employee                                        1
# Payment                                         1
# Training                                        1
# General                                         1
# Medical                                         1
# Technical,Crash,Campaign,Resolution,Urgent      1
# Name: count, dtype: int64
#
# 4 value counts:
# tag_2
# Product             389
# Security            158
# Bug                 129
# Integration         110
# Customer             84
#                    ...
# DigitalMarketing      1
# Accuracy              1
# System                1
# Unknown               1
# Upgrade               1
# Name: count, Length: 82, dtype: int64
#
# --- Cluster 3 Tag Counts ---
#
# 0 value counts:
# type
# Incident    1357
# Problem      259
# Change        90
# Request       48
# Name: count, dtype: int64
#
# 1 value counts:
# queue
# Technical Support                  838
# IT Support                         234
# Product Support                    232
# Service Outages and Maintenance    177
# Customer Service                   102
# Returns and Exchanges               65
# Billing and Payments                52
# Sales and Pre-Sales                 19
# Human Resources                     19
# General Inquiry                     16
# Name: count, dtype: int64
#
# 2 value counts:
# priority
# high      1206
# medium     350
# low        198
# Name: count, dtype: int64
#
# 3 value counts:
# tag_1
# Bug               585
# Outage            220
# Crash             151
# Security          150
# Technical         129
# Network           107
# Performance        83
# Feedback           72
# Feature            49
# Login              40
# Disruption         38
# Billing            30
# Breach             24
# Incident           19
# Customer            8
# Hardware            6
# Product             5
# Documentation       4
# Integration         3
# Campaign            3
# Tech Support        3
# API                 2
# Website             2
# Digital             2
# Maintenance         2
# IT                  2
# Disappearance       1
# System Failure      1
# Data                1
# Account             1
# Payment             1
# Server              1
# Marketing           1
# Cybersecurity       1
# Urgent              1
# Encryption          1
# Issue               1
# Access              1
# HR                  1
# Social Media        1
# SocialMedia         1
# Name: count, dtype: int64
#
# 4 value counts:
# tag_2
# Performance     507
# Disruption      197
# Network         185
# Crash           162
# Bug             109
#                ...
# Ad                1
# Connectivity      1
# Guidance          1
# Social Media      1
# Return            1
# Name: count, Length: 66, dtype: int64
#
# --- Cluster 4 Tag Counts ---
#
# 0 value counts:
# type
# Request     637
# Incident    198
# Problem     149
# Change       97
# Name: count, dtype: int64
#
# 1 value counts:
# queue
# Billing and Payments               757
# Product Support                     79
# Customer Service                    60
# IT Support                          58
# Sales and Pre-Sales                 40
# Technical Support                   28
# Returns and Exchanges               24
# Human Resources                     21
# General Inquiry                      8
# Service Outages and Maintenance      6
# Name: count, dtype: int64
#
# 2 value counts:
# priority
# medium    711
# high      192
# low       178
# Name: count, dtype: int64
#
# 3 value counts:
# tag_1
# Billing          599
# Feature          133
# Security          75
# Customer          68
# Feedback          67
# Technical         41
# Product           33
# Documentation     13
# Sales             13
# Payment           11
# Performance        8
# IT                 2
# Onboarding         2
# Guidance           2
# Integration        2
# Training           2
# Strategy           2
# Breach             1
# Returns            1
# Network            1
# Cybersecurity      1
# Pricing            1
# Features           1
# Bug                1
# Employee           1
# Name: count, dtype: int64
#
# 4 value counts:
# tag_2
# Payment           389
# Documentation     114
# Product            96
# Customer           53
# Feature            48
# Sales              41
# Account            40
# Technical          38
# Strategy           25
# Security           23
# Feedback           20
# Refund             15
# Pricing            15
# Integration        15
# Performance        13
# Bug                13
# Guidance           11
# Marketing          11
# Billing            10
# Compliance          8
# Network             7
# Medical             6
# Breach              5
# Digital             4
# Invoice             4
# Healthcare          3
# Inquiry             3
# Upgrade             3
# Hardware            3
# Subscription        3
# Finance             3
# Disruption          2
# Tech Support        2
# Outage              2
# Notification        2
# Backup              2
# Resolution          2
# Training            2
# Employee            2
# Virus               2
# Investment          2
# Compatibility       1
# Encryption          1
# Analytics           1
# Software            1
# HR                  1
# Protocol            1
# Discrepancy         1
# Hospital            1
# Tools               1
# Implementation      1
# Service             1
# Correction          1
# Collaboration       1
# Support             1
# Adjustment          1
# Error               1
# Lead                1
# Incident            1
# Alert               1
# Name: count, dtype: int64
#
# --- Cluster 5 Tag Counts ---
#
# 0 value counts:
# type
# Incident    1423
# Problem      292
# Change        72
# Request       37
# Name: count, dtype: int64
#
# 1 value counts:
# queue
# Technical Support                  838
# Product Support                    333
# IT Support                         236
# Customer Service                   163
# Returns and Exchanges               83
# Service Outages and Maintenance     71
# Sales and Pre-Sales                 32
# Billing and Payments                32
# Human Resources                     18
# General Inquiry                     18
# Name: count, dtype: int64
#
# 2 value counts:
# priority
# medium    1103
# high       517
# low        204
# Name: count, dtype: int64
#
# 3 value counts:
# tag_1
# Technical             1434
# Security               126
# Crash                   83
# Login                   46
# Outage                  34
# Customer                23
# Network                 16
# Breach                   7
# Product                  6
# Performance              6
# Order                    6
# HR                       4
# Disruption               4
# Billing                  4
# Digital                  3
# Feedback                 3
# Incident                 3
# Feature                  3
# Refund                   2
# Notification             1
# Campaigns                1
# Backup                   1
# Campaign                 1
# Critical Data Loss       1
# Project                  1
# Payment                  1
# Device                   1
# Encryption               1
# Returns                  1
# Account                  1
# Name: count, dtype: int64
#
# 4 value counts:
# tag_2
# Bug             672
# Security        181
# Integration     151
# Outage           95
# Customer         92
#                ...
# Malware           1
# Backup            1
# Service           1
# Docker            1
# Notification      1
# Name: count, Length: 82, dtype: int64

# %%
#Barchart for top tags in each cluster

tag_cols = ['tag_1', 'tag_2', 'tag_3', 'tag_4', 'tag_5']

fig, axes = plt.subplots(3, 2, figsize=(16, 12)) 
axes = axes.flatten()

for i, cluster_df in enumerate(cluster_data):
    tag_total = {}
    for tag in range(len(tag_cols)):
        counts = cluster_df.iloc[:, tag].value_counts()
        for tag_value, count in counts.items():
            if tag_value not in tag_total:
                tag_total[tag_value] = 0
            tag_total[tag_value] += count
    tag_total.pop('Unknown', None)

    sorted_tags = dict(sorted(tag_total.items(), key=lambda item: item[1], reverse=True)[:10])

    ax = axes[i] 
    ax.bar(sorted_tags.keys(), sorted_tags.values())
    ax.set_title(f'Cluster {i}', fontsize=14)
    ax.set_xlabel('Tag')
    ax.set_ylabel('Frequency')
    ax.set_xticklabels(sorted_tags.keys(), rotation=45)
    ax.grid(axis='y')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\1888424826.py:25: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(sorted_tags.keys(), rotation=45)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\1888424826.py:25: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(sorted_tags.keys(), rotation=45)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\1888424826.py:25: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(sorted_tags.keys(), rotation=45)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\1888424826.py:25: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(sorted_tags.keys(), rotation=45)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\1888424826.py:25: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(sorted_tags.keys(), rotation=45)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\1888424826.py:25: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(sorted_tags.keys(), rotation=45)

# %%
#plot for heatmap
cols = ['type', 'queue', 'priority']
all_counts = []

for cluster_df in cluster_data:
    total = {}
    for col in range(len(cols)):
        counts = cluster_df.iloc[:, col].value_counts()
        for value, count in counts.items():
            if value not in total:
                total[value] = 0
                total[value] += count
    
    all_counts.append(total)

heat_df = pd.DataFrame(all_counts).fillna(0)
heat_df.index = [f'Cluster {i}' for i in range(len(cluster_data))]

plt.figure(figsize=(14,8))
sns.heatmap(heat_df, cmap='coolwarm', annot=True, fmt='.0f')
plt.title('Heatmap of Type,Queue,Priority For Each Clusters')
plt.ylabel('Cluster')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Minhashing

# %%
# %pip install sympy
from sympy import nextprime

def get_k_shingles_from_document(k, document):
    shingles = set()
    for i in range(len(document) - k + 1):
        shingles.add(document[i:i+k])
    return shingles

def create_characteristic_matrix(docs, k):
    shingle_sets = []
    all_shingles = set()

    #  Generate shingle sets for each document
    for doc in docs:
        shingles = get_k_shingles_from_document(k, doc)
        shingle_sets.append(shingles)
        all_shingles.update(shingles)

    # Create the characteristic matrix
    characteristic_matrix = pd.DataFrame(index=pd.Index(all_shingles))

    #Fill the matrix
    for i, shingles in enumerate(shingle_sets):
        # Each column is a document ID (or index)
        characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)

    return characteristic_matrix


def generateSignatureMatrix(characterisitcMatrix, num_hashes):

    # Initing signature matrix
    sig_matrix = np.full([num_hashes, len(characterisitcMatrix.columns)], fill_value=np.inf)

    # h(row) = (A*row + B) % P
    Ahash = np.random.choice(range(0,10000), size=num_hashes) 
    Bhash = np.random.choice(range(0,10000), size=num_hashes)
    Phash = nextprime(characterisitcMatrix.shape[0]) # Getting a prime number greater than the number of rows in characteristic matrix

    for r in range(len(characterisitcMatrix)): # looping through rows of characteristic matrix
        hashvals = (Ahash * r + Bhash) % Phash # Generating list of hash values

        # Filling in each documents column of the signature matrix 
        for doc in range(len(characterisitcMatrix.columns)):
            if characterisitcMatrix.iloc[r,doc] == 1:
                sig_matrix[:,doc] = np.minimum(sig_matrix[:,doc], hashvals) # Choosing the min of the hash value or the signature matrix for each row of the signature matrix
    

    return sig_matrix
# Out:
# Requirement already satisfied: sympy in c:\users\charl\appdata\local\programs\python\python313\lib\site-packages (1.14.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\charl\appdata\local\programs\python\python313\lib\site-packages (from sympy) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
def find_top_k_similar(docs, row_numbers, new_doc, k_shingle=5, num_hashes=100, top_k=5):

    # Combine the new doc and existing docs into one list
    docs_to_compare = [new_doc] + list(docs)

    # Create characteristic and signature matrices
    char_matrix = create_characteristic_matrix(docs_to_compare, k_shingle)
    sig_matrix = generateSignatureMatrix(char_matrix, num_hashes)

    # Target vector is the first column (the new doc)
    target_vector = sig_matrix[:, 0]

    # Compare target to all other docs
    similarities = [
        sum(target_vector == sig_matrix[:, i]) / sig_matrix.shape[0]
        for i in range(1, sig_matrix.shape[1])
    ]

    # Zip similarities with original row numbers
    results = list(zip(row_numbers, similarities))

    # Sort by similarity descending
    results = sorted(results, key=lambda x: x[1], reverse=True)

    # Return top_k results
    return results[:top_k]

def predict_cluster(kmodes_model, new_row):
    centroids = kmodes_model.get_centroids()
    
    closest_cluster = 0
    closest_dist = kmodes_model._dist(centroids[0], new_row)

    for i, centroid in enumerate(centroids):
        d = kmodes_model._dist(centroid, new_row)
        if d < closest_dist:
            closest_cluster = i
            closest_dist = d

    return closest_cluster

# %%
import pandas as pd
import numpy as np

# Your new ticket data
new_row = [
    "Incident",         # type
    "Technical Support",# queue
    "high",             # priority
    "Technical",        # tag_1
    "Bug",              # tag_2
    "Performance",      # tag_3
    "Unknown",          # tag_4
    "Unknown"           # tag_5
]

new_ticket_body = (
    "unable to access the analytics dashboard after the software update "
    "tried restarting the server and clearing the cache but the issue remains "
    "need urgent support to resolve the crash"
)

# 1. Predict cluster index
predicted_cluster_idx = predict_cluster(kmode, new_row)
print(f"New ticket assigned to cluster {predicted_cluster_idx}")

# 2. Get indices of all rows in that cluster
cluster_row_numbers = clusters[predicted_cluster_idx].get_data()

# 3. Extract ticket bodies from original DataFrame
docs_in_cluster = df.iloc[cluster_row_numbers]['body'].fillna('').tolist()

# 4. Run MinHash similarity check
top_matches = find_top_k_similar(
    docs_in_cluster,
    cluster_row_numbers,
    new_ticket_body,
    k_shingle=5,
    num_hashes=100,
    top_k=5
)

# 5. Print results
print("\nTop 5 most similar tickets in the cluster:")
for i, (row_num, sim_score) in enumerate(top_matches, 1):
    print(f"Match #{i}: Row {row_num} with similarity {sim_score:.3f}")

# 6. Defragment your DataFrame to fix the PerformanceWarning
df = df.copy()
# Out:
# New ticket assigned to cluster 1
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# ...
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# C:\Users\charl\AppData\Local\Temp\ipykernel_26144\3413494697.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   characteristic_matrix[i] = characteristic_matrix.index.isin(shingles).astype(int)
# Top 5 most similar tickets in the cluster:
# Match #1: Row 6172 with similarity 0.270
# Match #2: Row 1915 with similarity 0.250
# Match #3: Row 11676 with similarity 0.220
# Match #4: Row 7012 with similarity 0.210
# Match #5: Row 8190 with similarity 0.200

# %%
# Print the new ticket body
print("\nNew Ticket Body:\n")
print(new_ticket_body)

# Print the bodies and answers of the top 5 most similar past tickets
print("\nSuggested Similar Tickets:\n")
for i, (row_pos, sim_score) in enumerate(top_matches, 1):
    try:
        ticket_body = df.iloc[row_pos]['body']
        ticket_answer = df.iloc[row_pos]['answer']
    except IndexError:
        ticket_body = "[Body not found]"
        ticket_answer = "[Resolution not found]"

    print(f"Match #{i} — Row {row_pos} — Similarity: {sim_score:.3f}")
    print("Ticket Body:\n", ticket_body)
    print("Resolution:\n", ticket_answer)
    print('-' * 100)
# Out:
# New Ticket Body:
#
# unable to access the analytics dashboard after the software update tried restarting the server and clearing the cache but the issue remains need urgent support to resolve the crash
#
# Suggested Similar Tickets:
#
# Match #1 — Row 6172 — Similarity: 0.270
# Ticket Body:
#  users are unable to access the updated dashboards and clearing the cache does not resolve the issue
# Resolution:
#  <name> is investigating the issue with the project dashboards that has been reported. I'm sorry to hear that users are unable to access them despite clearing the cache. Please provide the specific error messages that users are encountering when trying to access the dashboards. I would like to schedule a call to discuss the issue at a time that is convenient for you. My phone number is <tel_num>; I would prefer to have an alternate time if that works better.
# ----------------------------------------------------------------------------------------------------
# Match #2 — Row 1915 — Similarity: 0.250
# Ticket Body:
#  users are unable to access financial reports following the recent update the issue was resolved after restarting and clearing the cache successfully
# Resolution:
#  Dear [Name], we acknowledge the issue with accessing financial reports after the recent update. We understand that restarting and clearing the cache resolved the problem. Could you please provide details of the error message that users are receiving? It would be necessary for us to schedule a call at [Tel Num] to discuss the issue and work on a resolution. Please let us know a suitable time for the call, or if you prefer to continue via email, we are happy to assist. Your account number is [Acc Num].
# ----------------------------------------------------------------------------------------------------
# Match #3 — Row 11676 — Similarity: 0.220
# Ticket Body:
#  the data analytics tool experienced a crash during peak usage after restarting and clearing the cache the issue still persists
# Resolution:
#  Please investigate the data analytics tool issue. Kindly provide the error message you are receiving. If necessary, we may need to contact <tel_num> for further troubleshooting.
# ----------------------------------------------------------------------------------------------------
# Match #4 — Row 7012 — Similarity: 0.210
# Ticket Body:
#  investment optimization reports are not generating correctly after recent software updates restarting the applications and clearing caches did not resolve the issue
# Resolution:
#  Please investigate the problem with the investment reports generation. Contact us at <tel_num> to discuss troubleshooting steps and schedule a call at your convenience.
# ----------------------------------------------------------------------------------------------------
# Match #5 — Row 8190 — Similarity: 0.200
# Ticket Body:
#  encountered a system crash while using the jira project management tool the issue might have arisen due to heavy server load after restarting my desktop computer and clearing the cache the problem still persists
# Resolution:
#  Hello [Name], I'm sorry to hear that you're experiencing issues with the JIRA system. Thank you for your efforts in troubleshooting by restarting your computer and clearing the cache. To assist you better, could you please provide the error message you are receiving and the exact steps that led to the crash? Additionally, it would be helpful to know the specifications of your server and the number of users currently accessing the JIRA system. This information will help us better understand the issue and provide an accurate solution. Thank you.
# ----------------------------------------------------------------------------------------------------
