# %%
import sys
sys.path.append("../src")
from kmeans import Kmeans, Cluster
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("./test_data/pokedexg13.csv")
print(df.shape)
df.head(3)
# Out:
# (432, 13)
#    #       Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1  Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2    Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3   Venusaur  Grass  Poison    525  80      82       83      100      100
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False

# %%
"""" CLUSTER TEST """
test_kmean = Kmeans(1, df[['HP','Attack','Defense']], 0)
cluster = test_kmean.get_clusters()[0]

##### add/drop row tests #####
cluster.drop_row(0)
cluster.add_row(0)
print(cluster.get_data())
cluster.drop_row(0)
print(cluster.get_data())
print(cluster.get_centroid())
print()

#### Centroid tests ####
test_kmean.lookup_index(0)
cluster.add_row(0)
print(cluster.get_centroid())

cluster.add_row(1)
print(cluster.get_centroid())
# Out:
# Error: unable to remove row because it was not found in the cluster
# Row: 0
# [391, 0]
# [391]
# [65. 50. 70.]
#
# [55.  49.5 59.5]
# [56.66666667 53.66666667 60.66666667]

# %%
#### Cluster error test ###
cluster = Cluster(test_kmean)
print(cluster.get_error())
cluster.add_row(0)
print(cluster.get_centroid())
print(cluster.get_error())
print()

cluster.add_row(1)
print(cluster.get_centroid())
print(cluster.get_error())
# Out:
# 0
# [45. 49. 49.]
# 0.0
#
# [52.5 55.5 56. ]
# 294.99999999999994

# %%
full_test = Kmeans(4, df[['HP','Attack','Defense']], 0.05)
full_test.run_kmeans()
