# %%
import sys
sys.path.append("../src")
from kmeans import Kmeans, Cluster
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("./test_data/pokedexg13.csv")
print(df.shape)
df.head(3)
# Out:
# (432, 13)
#    #       Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1  Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2    Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3   Venusaur  Grass  Poison    525  80      82       83      100      100
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False

# %%
"""" CLUSTER TEST """
test_kmean = Kmeans(1, df[['HP','Attack','Defense']], 0)
cluster = test_kmean.get_clusters()[0]

##### add/drop row tests #####
cluster.drop_row(0)
cluster.add_row(0)
print(cluster.get_data())
cluster.drop_row(0)
print(cluster.get_data())
print(cluster.get_centroid())
print()

#### Centroid tests ####
test_kmean.lookup_index(0)
cluster.add_row(0)
print(cluster.get_centroid())

cluster.add_row(1)
print(cluster.get_centroid())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 """" CLUSTER TEST """
# ----> 2 test_kmean = Kmeans(1, df[['HP','Attack','Defense']], 0)
#       3 cluster = test_kmean.get_clusters()[0]
#       5 ##### add/drop row tests #####
#
# TypeError: Kmeans.__init__() missing 1 required positional argument: 'cat_cols'

# %%
#### Cluster error test ###
cluster = Cluster(test_kmean)
print(cluster.get_error())
cluster.add_row(0)
print(cluster.get_centroid())
print(cluster.get_error())
print()

cluster.add_row(1)
print(cluster.get_centroid())
print(cluster.get_error())
# Out:
# 0
# [45. 49. 49.]
# 0.0
#
# [52.5 55.5 56. ]
# 294.99999999999994

# %%
full_test = Kmeans(4, df[['HP','Attack','Defense', 'Type 1', 'Type 2']], ['HP','Attack','Defense'], ['Type 1', 'Type 2'], 0.05, 0.995)
full_test.run_kmeans()
# Out:
# 485.2050646898734
# 467.6053270302947
# 468.99962508326513
# 468.11115579193347
# 467.3416593483873
# 467.2097194809731
# 467.0816484862247
# 467.08714770174265
